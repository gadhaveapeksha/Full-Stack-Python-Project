# %% [markdown]
# # Welcome Day 1

# %% [raw]
# #python variable

# %%
v=5
v
# Out:
# 5

# %% [raw]
# #Variable is not define start with number

# %%
5 = v
5
# Out:
#   Cell In[2], line 1
#     5 = v
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
1nit=34
1=nit
# Out:
#   Cell In[3], line 1
#     1nit=34
#     ^
# SyntaxError: invalid decimal literal

# %%
nit1=34
nit1
# Out:
# 34

# %%
nit1 = 34
nit1
# Out:
# 34

# %% [raw]
# #Python is a case sencitive lang.

# %%
v1 = 6
a1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 v1 = 6
# ----> 2 a1
#
# NameError: name 'a1' is not defined

# %%
v1 = 6
v1
# Out:
# 6

# %% [raw]
# # It is stored recent information

# %%
v
nit1
v1
# Out:
# 6

# %% [raw]
# # print() function is use to all variable

# %%
print(v)
print(nit1)
print(v1)
# Out:
# 5
# 34
# 6

# %% [raw]
# #Python is case sencitive lang

# %%
NIT2 = 56
nit
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 NIT2 = 56
# ----> 2 nit
#
# NameError: name 'nit' is not defined

# %%
NIT2 = 56
NIT2
# Out:
# 56

# %% [raw]
# #Special caracter is not allow to variable decleration

# %%
nit@ = 56
nit@
# Out:
#   Cell In[15], line 1
#     nit@ = 56
#          ^
# SyntaxError: invalid syntax

# %%
nit4 = 56
nit4
# Out:
# 56

# %%
ex% = 49
ex%
# Out:
#   Cell In[17], line 1
#     ex% = 49
#         ^
# SyntaxError: invalid syntax

# %%
ex = 49
ex
# Out:
# 49

# %% [raw]
# #Only allow (_) character because it is stored privius output

# %%
_
# Out:
# 49

# %%
_ + 1
# Out:
# 50

# %% [raw]
# # reserve word also called as keyword

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
# using len() function the total keyword is measuring

# %%
len(keyword.kwlist)
# Out:
# 35

# %% [raw]
# #do nat use this key word for declaring variable

# %%
True=5
# Out:
#   Cell In[6], line 1
#     True=5
#     ^
# SyntaxError: cannot assign to True

# %%
False = 4
# Out:
#   Cell In[7], line 1
#     False = 4
#     ^
# SyntaxError: cannot assign to False

# %% [markdown]
# # Rules:-

# %% [raw]
# #variable is case sencitive
# #variable dose not start with no but ends with no
# #special characters is not allow and expect only _
# #keywords or reserve words are not declare is a variable

# %%
# Variables in Python

first_name = 'Apeksha'
last_name = 'Gadhave'
country = 'Maharashtra'
city = 'Pune'
age = 21
is_married = False
skills = ['HTML', 'CSS', 'JS', 'React', 'Python']
person_info = {
    'firstname':'Komal', 
    'lastname':'Gadhave', 
    'country':'Maharashtra',
    'city':'mumbai',
    }

# Printing the values stored in the variables

print('First name:', first_name)
print('First name length:', len(first_name))
print('Last name: ', last_name)
print('Last name length: ', len(last_name))
print('Country: ', country)
print('City: ', city)
print('Age: ', age)
print('Married: ', is_married)
print('Skills: ', skills)
print('Person information: ', person_info)

# Declaring multiple variables in one line

first_name, last_name, country, age, is_not_married = 'Apeksha', 'Gadhave', 'Maharashtra', 21, False

print(first_name, last_name, country, age, is_not_married)
print('First name:', first_name)
print('Last name: ', last_name)
print('Country: ', country)
print('Age: ', age)
print('Married: ', is_not_married)
# Out:
# First name: Apeksha
# First name length: 7
# Last name:  Gadhave
# Last name length:  7
# Country:  Maharashtra
# City:  Pune
# Age:  21
# Married:  False
# Skills:  ['HTML', 'CSS', 'JS', 'React', 'Python']
# Person information:  {'firstname': 'Komal', 'lastname': 'Gadhave', 'country': 'Maharashtra', 'city': 'mumbai'}
# Apeksha Gadhave Maharashtra 21 False
# First name: Apeksha
# Last name:  Gadhave
# Country:  Maharashtra
# Age:  21
# Married:  False
