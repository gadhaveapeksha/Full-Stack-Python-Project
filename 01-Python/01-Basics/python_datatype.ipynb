# %% [raw]
# # 1st create variable

# %%
i = 5
i
# Out:
# 5

# %% [raw]
# # type function

# %%
type()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 type()
#
# TypeError: type() takes 1 or 3 arguments

# %% [raw]
# # means at list 1 or more argument can be pass in the function

# %% [raw]
# 1.Integer

# %%
type(i)
# Out:
# int

# %%
i
# Out:
# 5

# %% [raw]
# #id () ...(address function is used to check address of variable)

# %%
id(i)
# Out:
# 140707959727352

# %%
age = 34
age
# Out:
# 34

# %%
id(type(age))
# Out:
# 140707958890304

# %%
print(type(age))
print(id(age))
# Out:
# <class 'int'>
# 140707959728280

# %% [raw]
# 2.Float

# %%
f = 110.22
f
# Out:
# 110.22

# %%
type(f)
# Out:
# float

# %%
id(f)
# Out:
# 2258493377584

# %%
print(type(f))
print(id(f))
# Out:
# <class 'float'>
# 2258493377584

# %% [raw]
# 3.bool

# %%
b = True
b
# Out:
# True

# %%
b = True
b
# Out:
# True

# %%
type(b)
# Out:
# bool

# %%
b1 = False
b1
# Out:
# False

# %%
p = 10
q = 10
print(p)
print(q)
# Out:
# 10
# 10

# %%
print(id(p)) #it variable stored same memory location 
print(id(q))
# Out:
# 140706970854808
# 140706970854808

# %%
print(p)
print(q)
# Out:
# 10
# 10

# %%
p = p + 10 #variable overwriting
p          #value are changed so location automatically changed
# Out:
# 20

# %%
print(b)
print(b1)
# Out:
# True
# False

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
True+False
# Out:
# 1

# %%
True+True
# Out:
# 2

# %%
True*0
# Out:
# 0

# %%
False*0
# Out:
# 0

# %%
False/True
# Out:
# 0.0

# %%
False//True
# Out:
# 0

# %% [raw]
# 4.Complex

# %%
c = 10+20j
c
# Out:
# (10+20j)

# %%
type(c)
# Out:
# complex

# %%
c1 = 20+30J
c1
# Out:
# (20+30j)

# %%
print(c)
print(c1)
# Out:
# (20+30j)
# (20+30j)

# %%
c.real
# Out:
# 20.0

# %%
c.imag
# Out:
# 30.0

# %%
c + c1
# Out:
# (40+60j)
