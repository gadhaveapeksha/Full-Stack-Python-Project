# %% [markdown]
# # Typecasting

# %%
si = 'WELCOME'
si
# Out:
# 'WELCOME'

# %% [markdown]
# #indexing and slicing in string concept

# %%
si[:6]
# Out:
# 'WELCOM'

# %%
si
# Out:
# 'WELCOME'

# %% [markdown]
# #Step slicing

# %%
si[0:7:2]  #Forword slicing
# Out:
# 'WLOE'

# %%
si[0:7:3]
# Out:
# 'WCE'

# %%
si[3:7:1]
# Out:
# 'COME'

# %%
si
# Out:
# 'WELCOME'

# %%
si[-6:-1]   #Backword slicing
# Out:
# 'ELCOM'

# %%
si[-5:-2]
# Out:
# 'LCO'

# %%
si[-7:-1]
# Out:
# 'WELCOM'

# %%
si
# Out:
# 'WELCOME'

# %%
si[::2]  #slicing all word in two step
# Out:
# 'WLOE'

# %%
si[::1]
# Out:
# 'WELCOME'

# %%
si
# Out:
# 'WELCOME'

# %%
si[::-1]
# Out:
# 'EMOCLEW'

# %%
si[::-2]
# Out:
# 'EOLW'

# %%
si[::-1]
# Out:
# 'EMOCLEW'

# %% [markdown]
# # Python Typecasting

# %%
110.33
# Out:
# 110.33

# %% [markdown]
# #other datatype to int

# %%
int(110.33) #we can convert float to int
# Out:
# 110

# %%
int(True)  #we can convert bool to int
# Out:
# 1

# %%
int(False)
# Out:
# 0

# %%
int(1+2j)  #we can not convert bool to int
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 int(1+2j)  #we can convert bool to int
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'complex'

# %%
int('10')   # we can convert number string  to int
# Out:
# 10

# %%
int('Ten')   #we can not convert text string into int
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 int('Ten')
#
# ValueError: invalid literal for int() with base 10: 'Ten'

# %% [markdown]
# #other datatype to float

# %%
float(10)
# Out:
# 10.0

# %%
float(20)
# Out:
# 20.0

# %%
float(True)
# Out:
# 1.0

# %%
float(False)
# Out:
# 0.0

# %%
float(1+2j) # we can not convert complex to float
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 float(1+2j)
#
# TypeError: float() argument must be a string or a real number, not 'complex'

# %%
float('100')
# Out:
# 100.0

# %%
float('Hundred') #we can not convert string  text to float
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 float('Hundred')
#
# ValueError: could not convert string to float: 'Hundred'

# %% [markdown]
# #other datatype to boolean

# %%
bool(110)
# Out:
# True

# %%
bool(110.33)
# Out:
# True

# %%
bool(True)
# Out:
# True

# %%
bool(False)
# Out:
# False

# %%
bool('Ten')
# Out:
# True

# %%
bool(10)
# Out:
# True

# %%
bool(-6)
# Out:
# True

# %%
bool(1+2j)
# Out:
# True

# %% [markdown]
# #All other datatype to complex

# %%
complex(5)
# Out:
# (5+0j)

# %%
complex(45.34)
# Out:
# (45.34+0j)

# %%
complex(43,34)
# Out:
# (43+34j)

# %%
complex('one') ## we can not convert String to complex
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 complex('one')
#
# ValueError: complex() arg is a malformed string

# %%
complex('34')
# Out:
# (34+0j)

# %%
complex(True)
# Out:
# (1+0j)

# %%
complex(False)
# Out:
# 0j

# %%
complex('24','25')#complex can nat take second argument in sting format
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 complex('24','25')
#
# TypeError: complex() argument 'real' must be a real number, not str

# %%
complex(5,3,5) #only two argument is accepted
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 complex(5,3,5)
#
# TypeError: complex() takes at most 2 arguments (3 given)

# %% [markdown]
# #all othe datype to string

# %%
str(10)
# Out:
# '10'

# %%
str(45.35)
# Out:
# '45.35'

# %%
str(True)
# Out:
# 'True'

# %%
str(False)
# Out:
# 'False'

# %%
str("sfdf")
# Out:
# 'sfdf'

# %%
str(1+2j)
# Out:
# '(1+2j)'

# %% [markdown]
# #1.other datatye to int expect complex & text string
#  2.other datatye to float expect complex & text string
#  3.other datatye to bool every type conversion is possible
#  4.other datatye to complex every type conversion is possible expect only one string is valid
#   5.other datatye to string every type conversion is possible
