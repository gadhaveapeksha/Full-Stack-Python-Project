# %% [markdown]
# # 1.string

# %% [markdown]
# #Three type can be write string 1.'' ,2." " ,3.'''  '''

# %%
s = 'welcome' #single quotes
s
# Out:
# 'welcome'

# %%
s1 = "welcome" #double quotes
s1
# Out:
# 'welcome'

# %%
s2 = '''welcometo
         naresh it
         welcome''' #triple quotes
s2
# Out:
# 'welcometo\n         naresh it\n         welcome'

# %% [markdown]
# # string index

# %% [markdown]
# #forwoed index

# %%
si = 'welcome'
si
# Out:
# 'welcome'

# %%
si[4]
# Out:
# 'o'

# %%
si[7]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 si[7]
#
# IndexError: string index out of range

# %% [markdown]
# #Backword index

# %%
si
# Out:
# 'welcome'

# %%
si[-1]
# Out:
# 'e'

# %%
si[-7]
# Out:
# 'w'

# %% [markdown]
# # slicing. It is define with  (colon)

# %% [markdown]
# #si[:]--print all
# #si[1:4]--print 1 to 4

# %% [markdown]
# #forword slicing

# %%
si
# Out:
# 'welcome'

# %%
si[:]
# Out:
# 'welcome'

# %%
si[1:4]
# Out:
# 'elc'

# %%
si[0:6]
# Out:
# 'welcom'

# %%
si
# Out:
# 'welcome'

# %%
si[3:10]
# Out:
# 'come'

# %%
si[10] #this is not a slicing
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 si[10]
#
# IndexError: string index out of range

# %%
si[3:5]
# Out:
# 'co'

# %%
si[3:]
# Out:
# 'come'

# %%
si[:4]
# Out:
# 'welc'

# %%
si[:6]
# Out:
# 'welcom'

# %% [markdown]
# #Backword slicing

# %%
si
# Out:
# 'welcome'

# %%
si[-3:]
# Out:
# 'ome'

# %%
si[:-6]
# Out:
# 'w'

# %%
si[len(si)-1] # Last character in string using len function
# Out:
# 'e'

# %%
si[-6:]
# Out:
# 'elcome'

# %% [markdown]
# #Update & Delete String

# %%
si
# Out:
# 'welcome'

# %%
si[0:5]
# Out:
# 'welco'

# %% [markdown]
# #String concatenation

# %%
a1=34
b1=39
c1=a1+b1
print(c1)
# Out:
# 73

# %%
x1 = 45
x2 = 4
z1 = x1*x2
print
